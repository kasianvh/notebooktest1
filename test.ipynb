# %%
# Opgaven {#opgaven .unnumbered}

Bij deze PO gaan jullie de gegevens uit het databestand
\"Speeddatingdata' onderzoeken. Daarbij probeer je conclusies te trekken
uit de data. We gaan ervan uit dat deze dataset een representatieve
steekproef is van alle speeddates in de VS.

Beschrijf bij elke vraag je gedachtegang en hoe je tot een oplossing
bent gekomen en licht je antwoorden waar mogelijk toe met een geschikte
(grafische) representatie. In de opgave wordt vaak een hint gegeven op
welke manier de opgave is op te lossen (meestal draaitabel/pivot table),
maar op een andere manier de vraag oplossen mag natuurlijk ook.

Elke regel van het bestand bevat de gegevens van een date. Je ziet
bijvoorbeeld in het eerste record dat het bij deze date om een 21
-jarige vrouw gaat met ID 10001, dat als doel opgegeven heeft om nieuwe
mensen te ontmoeten. Haar gesprekspartner met ID 10011, in het record ID
other genoemd, is 27 jaar.

# video
<iframe width="560" height="315" src="https://www.youtube.com/embed/dQw4w9WgXcQ?si=wxHO3xKL5ok_uqoZ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

## Excel tabellen  {#excel-tabellen .unnumbered}

Bij dit PO zal klaarblijkelijk zijn dat het gebruiken van een draaitabel
of engels genaamd *pivot table* vaak terug komen. Dit komt vooral omdat
draaitabellen grootte dataset kan omzetten in kleinere data sets.
Draaitabellen kunnen ook helpen bij het filteren van veel overbodige
informatie dat niet relevant is tot wat je aan het onderzoeken bent.
Data-analyse dat met Excel wordt gedaan is dus ook vooral afhankelijk
van het kunnen maken van een goede draaitabel die goed toepasbaar is op
de gegeven probleem stelling.

Om vraag 1 tot en met 4 te beantwoorden is het handig om video 5 te
bekijken. Video 5 legt uit hoe je een Excel tabel kunt maken om bepaalde
informatie te zoeken in een dataset. Ook is het handig om video 1 van
06:10 tot en met 07:30 te bekijken.\
Uitleg hoe je data in een tabel zet en hoe je hiermee werkt, zodat je
makkelijk de vragen kunt beantwoorden.

Als je in de praktijk aan een dataset gaat werken begin je met de
verkenning van de data. Dit doen wij met de volgende vragen:

1.  Beantwoord de volgende verkennende vragen:

    -   Hoeveel mensen van elk geslacht heb je? $(1p)$

    -   Hoeveel mensen van elke leeftijd heb je? $(1p)$

    -   Hoeveel mensen vinden godsdienst belangrijk (imp religion
        $\geq 7)$? $(1p)$

    -   Wat is de gemiddelde leeftijd bij mannen? Geef hiervan een
        interpretatie. $(1p)$

<!-- -->

2.  In deze vraag gaan we de data visualiseren. Hiervoor is het handig
    om video 5 gezien te hebben mocht je nog niet weten hoe je grafieken
    moet maken.

    -   Maak een (of twee) histogram(men) die de leeftijd van mannen en
        vrouwen laat zien. Wat merk je op?

    -   Maak een cirkeldiagram (pie chart) van de verdeling van de
        rassen die mee hebben gedaan aan de speeddating.

    -   Wat betekent de \" \* \" die je ziet in je cirkeldiagram?

Het bestand telt 8388 records met daarin de gegevens van een speeddate.
Omdat elke speeddate tweemaal beschreven wordt, zijn de gegevens van één
speeddate te vinden in twee rijen . Fisman en lyengar hebben dus in
totaal $\frac{8388}{2}=4194$ speeddates geanalyseerd. Dit betekent dat
voor de hele dataset het volgende geldt: Als je de gegevens van de 4194
speeddates wilt analyseren en niet alles dubbel wilt tellen, dan
selecteer je bij de variabele gender alleen de mannen of alleen de
vrouwen.

2.  Bereken hoeveel procent van de speeddates in deze onderzoeksgroep de
    vrouwelijke deelnemer als doel had om nieuwe mensen te ontmoeten.
    $(2 p)$

    *Hint: Ga als volgt te werk. 1) Hoeveel vrouwen deden in totaal
    mee.\
    2) Hoeveel vrouwen hadden als doel om nieuwe mensen te ontmoeten.\
    3) Bereken het percentage.*

3.  Bereken bij welk percentage van de speeddates in deze
    onderzoeksgroep de mannelijke deelnemers $0-<5$ jaar ouder (dus even
    oud, $1,2,3$ of 4 jaar ouder) waren dan de vrouwelijke deelnemers.
    $(5 p)$

    *Hint: maak een kolom met leeftijdsverschil*

4.  -   Wat is er met deelnemer met ID 10013 aan de hand? Beschrijf deze
        deelnemer. (2p)

    -   Wat kan je nu zeggen over de gehele data set als het gaat om het
        aantal personen dat meedoet en het aantal speeddates? (1pt)

![image](opgave 5.png)

Bekijk video 7: Draaitabellen

5.  1.  Voor één van de groepen, de mannen of de vrouwen, is godsdienst
        belangrijker dan voor de andere groep. Maak een draaitabel aan
        met importance relgion tegen over gender, vergelijkbaar als in
        figuur [1](#fig:frequentiepolygoon){reference-type="ref"
        reference="fig:frequentiepolygoon"}. $(1p)$

    2.  Vinden mannen of vrouwen religie het belangrijkst in speeddaten?
        Beantwoord deze vraag door een cumulatieve frequentiepolygoon te
        maken van beide groepen (Met een cumulatieve frequentiepolygoon
        kun je deze twee groepen met elkaar vergelijken). $(2p)$

        *Hint: Zet de draaitabel in: Show values as % of column total.
        Maak voor mannen en vrouwen een kolom aan naast de draaitabel en
        op plek 1 waarde 1,plek 2 waarde 1+2 enzovoort.*

![Hulptabel voor het maken van een relatieve cumulatieve
frequentiepolygoon](Tabel frequentie polygoon 2.png){#fig:frequentiepolygoon}

6.  In deze opgave gaan we een boxplot maken. Hiervoor is het handig om
    video 4 (vanaf 04:00) te bekijken als je nog niet weet hoe dit moet.

    -   Maak een boxplot van de variabele \"cor int\". (1pt)

    -   Geef een schatting van het hoogste- en het laagste getal. Geef
        ook een schatting van Q1, Q3 en de mediaan.(1pt)

<!-- -->

6.  Onderzoek of voor de speeddates in deze onderzoeksgroep de volgende
    stelling juist is: \"Mannen geven na een speeddate als beslissing
    (decision) vaker 'yes' aan dan vrouwen.\" $(1p)$

Voor de vragen 7 tot en met 9 is het handig om video 8 te bekijken tot
en met tijdstip 06:05.

7.  Waarschijnlijk hangt de beslissing 'yes' of 'no' samen met het
    totaal aantal punten dat gegeven wordt op de onderdelen attractive
    $\mathrm{t} / \mathrm{m}$ shared interests (attr tm shar). Maak een
    nieuwe kolom 'totaal_aantal_punten' die het totaal van de kolommen
    attr $\mathrm{t} / \mathrm{m}$ shar weergeeft.

    Maak vervolgens een kruistabel bij de variabelen
    totaal_aantal_punten en decision. Kies voor 15 klassen met
    beginwaarde 35 en klassebreedte 1. wtf is een kruistabel en waarom
    heb je dat nodig. denk dat dit veel makkelijker kan met een
    draaitabel

    1.  Ga aan de hand van de kruistabellen van mannen en vrouwen na of
        er een verband is tussen de beslissing 'yes'/'no' en het totaal
        aantal punten. $(4p)$

    2.  Ga na of er in dit verband een verschil is tussen mannen en
        vrouwen. $(4p)$

<!-- -->

8.  Onderzoek of een speeddate tussen deelnemers van hetzelfde ras vaker
    tot een match binnen deze onderzoeksgroep leidt dan een speeddate
    tussen deelnemers die niet van hetzelfde ras zijn. $(3p)$

9.  De onderzoekers verwachtten van tevoren dat bij een speeddate
    gemiddeld genomen de man de vrouw aantrekkelijker (attractive) vindt
    dan andersom. Onderzoek of dit voor de gegevens van deze
    onderzoeksgroep juist is. Licht je antwoord toe. $(4 p)$

De onderzoekers hebben voorafgaand aan elk speeddate event aan de
deelnemers naar hun interesses gevraagd. Zodoende konden ze van elke
speeddate aangeven in hoeverre de interesses van de beide deelnemers
overeenkwamen. Dat is terug te vinden in de variabele cor_int
(correlation of interests).

De correlatie is een getal tussen - 1 en 1 . Als de correlatie een
positief getal is, dan is er sprake van gemeenschappelijke interesses.
Hoe hoger de correlatie, hoe meer de interesses van de gesprekspartners
overeenkomen.

We laten ze toch geen normaalverdeling vinden? wat boeit dit nou

10. Bekijk de variabele cor_int.

    1.  Geef gemiddelde, mediaan en modus van cor_int. $(3p)$. Hiervoor
        zou je ook een totalenrij kunen gebruiken. Zie video 5 op
        tijdstip 4:30.

    2.  Een van de vuistregels van de normale verdeling zegt iets over
        het percentage waarnemingen dat minder dan één standaarddeviatie
        afwijkt van het gemiddelde. Geef deze vuistregel en onderzoek of
        de variabele cor_int (bij benadering) aan deze vuistregel
        voldoet. $(6p)$. Zie video 8 groeperen en draaigrafieken tot en
        met tijdstip 3:10. Hint: Kies de juiste getallen voor \"Beginnen
        bij\", \"Eindigen bij\" en Op.

    3.  Onderzoek met behulp van een frequentiepolygoon of de variabele
        cor_int (bij benadering) normaal verdeeld is. $(2p)$ Hier moet
        nog een verwijzing komen naar een video hoe je een
        frequentiepolygoon maakt .

<!-- -->

11. Onderzoek of de volgende stelling waar is:

\"Als je een willekeurige speeddate uit deze dataset zou kiezen en je
weet dat de cor_int van die speeddate groter is dan 0,5, dan is de kans
op een match bij deze speeddate groter dan 0,5 \". Licht je antwoord
toe. $(3p)$

12. Geef telkens aan waarom onderstaand onderzoek wel of niet mogelijk
    is (Je hoeft het dus niet te onderzoeken. Een Ja/Nee antwoord met
    uitleg waarom wel/niet is voldoende):

    1.  Je kunt met behulp van de data in de dataset onderzoeken of de
        deelnemers een speeddate van 4 minuten te kort, te lang of
        precies goed vinden. $(1p)$

    2.  Je kunt met behulp van de data in de dataset onderzoeken of het
        moment van de speeddate (vroeg of laat tijdens het event) van
        invloed is op de beslissing 'yes' of 'no'. $(1p)$

    3.  Je kunt met behulp van de data in de dataset onderzoeken of
        deelnemers die zichzelf aantrekkelijk vinden meer kans hebben op
        een match dan deelnemers die zichzelf niet zo aantrekkelijk
        vinden. $(1p)$

    4.  Je kunt met behulp van de data in de dataset onderzoeken of er
        bij grotere leeftijdsverschillen tussen de man en de vrouw vaker
        sprake is van een match. $(1p)$

als we de onderzoekscyclus erin gooien, moeten we dat dan niet in het
begin al noemen?

De onderzoekers Fisman en lyengar hebben bij hun studie de empirische
onderzoekscyclus doorlopen. Zoals je weet, houdt de empirische cyclus
het volgende in:

-   een probleem omschrijven (theoretiseren);

-   een onderzoeksplan hierover opstellen, met operationalisering van
    variabelen;

-   verwachtingen over de uitkomsten uitspreken;

-   data verzamelen;

-   data analyseren;

-   conclusies trekken;

-   evalueren en nieuwe problemen voorleggen.

Fisman en lyengar beschrijven hun probleemstelling met deze hoofdvraag:
What influences love at first sight? (Or, at least, love in the first
four minutes?) (dus: 'Wat is van invloed op liefde op het eerste
gezicht? Of, op zijn minst, liefde in de eerste vier minuten')

Daarop ontwikkelen ze hun onderzoeksplan: ze gaan data verzamelen door
middel van het organiseren van speed date events, waarbij deelnemers
voorafgaand aan en tijdens het event data aanleveren.

13. Vind je dat het organiseren van speeddate events past bij de
    probleemstelling? Met andere woorden: zorgt het organiseren van
    speed date events ervoor dat Fisman en lyengar hun hoofdvraag kunnen
    beantwoorden? Licht je antwoord toe. $(3p)$

$\mathrm{Na}$ het verzamelen en analyseren van de data willen de
onderzoekers conclusies trekken. Je kunt alleen conclusies trekken op
grond van daadwerkelijk verzamelde data. Niet elke conclusie is daarom
mogelijk.

14. Beschrijf welke data nog meer verzameld hadden moeten worden om na
    te gaan of er een verband is tussen de godsdienst die een deelnemer
    heeft en het doel van zijn/haar gespreksdeelname. $(1p)$

15. Een laatste stap in de empirische cyclus is: evalueren en nieuwe
    problemen voorleggen. Bedenk twee nieuwe probleemstellingen die met
    deze dataset beantwoord kunnen worden. $(2p)$

# EINDE {#einde .unnumbered}
